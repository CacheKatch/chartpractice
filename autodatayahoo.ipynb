# %%
from pandas_datareader import data as pdr
from yahoo_finance import Share as sshare
from yahoo_fin import stock_info as si 
from pandas import ExcelWriter
import yfinance as yf
import pandas as pd
import datetime
import time
yf.pdr_override()

# %%
start_date = datetime.datetime.now() - datetime.timedelta(days=365)
end_date =datetime.date.today()

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# C:\Users\caro_\anaconda3\envs\scanyahoo\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# C:\Users\caro_\anaconda3\envs\scanyahoo\lib\pkgutil.py:107: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   yield from walk_packages(path, info.name+'.', onerror)
# DateTime            cgitb               nntplib             sysconfig
# IPython             chardet             normalizeForInterpreter tabnanny
# __future__          chartstock_tutorial normalizeSelection  tarfile
# _abc                chunk               nt                  telnetlib
# _ast                cmath               ntpath              tempfile
# _asyncio            cmd                 ntsecuritycon       test
# _bisect             cmftutorial         nturl2path          testlauncher
# _blake2             code                numbers             tests
# _bootlocale         codecs              numpy               textwrap
# _bz2                codeop              odbc                this
# _codecs             collections         opcode              threading
# _codecs_cn          colorama            openpyxl            time
# _codecs_hk          colorsys            operator            timeit
# _codecs_iso2022     commctrl            optparse            timer
# _codecs_jp          compileall          os                  tkinter
# _codecs_kr          completion          pandas              token
# _codecs_tw          concurrent          pandas_datareader   tokenize
# _collections        configparser        parse               tornado
# _collections_abc    contextlib          parser              tqdm
# _compat_pickle      contextvars         parso               trace
# _compression        copy                pathlib             traceback
# _contextvars        copyreg             pdb                 tracemalloc
# _csv                crypt               perfmon             traitlets
# _ctypes             cssselect           pickle              tty
# _ctypes_test        csv                 pickleshare         turtle
# _datetime           ctypes              pickletools         turtledemo
# _decimal            curses              pip                 types
# _distutils_hack     cythonmagic         pipes               typing
# _dummy_thread       dataclasses         pkg_resources       unicodedata
# _elementtree        datetime            pkgutil             unittest
# _functools          dateutil            platform            urllib
# _hashlib            dbi                 plistlib            urllib3
# _heapq              dbm                 poplib              uu
# _imp                dde                 posixpath           uuid
# _io                 decimal             pprint              venv
# _json               decorator           printEnvVariables   visualstudio_py_testlauncher
# _locale             difflib             printEnvVariablesToFile vscode_datascience_helpers
# _lsprof             dis                 profile             w3lib
# _lzma               distutils           prompt_toolkit      warnings
# _markupbase         doctest             pstats              wave
# _md5                dummy_threading     pty                 wcwidth
# _msi                email               py_compile          weakref
# _multibytecodec     encodings           pyclbr              webbrowser
# _multiprocessing    ensurepip           pydoc               websockets
# _opcode             enum                pydoc_data          wheel
# _operator           errno               pyee                win2kras
# _osx_support        et_xmlfile          pyexpat             win32api
# _overlapped         fake_useragent      pygments            win32clipboard
# _pickle             faulthandler        pyls_jsonrpc        win32com
# _py_abc             feedparser          pyppeteer           win32con
# _pydecimal          filecmp             pyquery             win32console
# _pyio               fileinput           pythoncom           win32cred
# _queue              fnmatch             pytz                win32crypt
# _random             formatter           pyvsc-run-isolated  win32cryptcon
# _sha1               fractions           pywin               win32event
# _sha256             ftplib              pywin32_bootstrap   win32evtlog
# _sha3               functools           pywin32_testutil    win32evtlogutil
# _sha512             gc                  pywintypes          win32file
# _signal             genericpath         queue               win32gui
# _sitebuiltins       getopt              quopri              win32gui_struct
# _socket             getpass             random              win32help
# _sqlite3            gettext             rasutil             win32inet
# _sre                glob                re                  win32inetcon
# _ssl                gzip                regcheck            win32job
# _stat               hashlib             regutil             win32lz
# _string             heapq               reprlib             win32net
# _strptime           hmac                requests            win32netcon
# _struct             html                requests_html       win32pdh
# _symtable           http                rlcompleter         win32pdhquery
# _testbuffer         idlelib             rmagic              win32pdhutil
# _testcapi           idna                runJediLanguageServer win32pipe
# _testconsole        imaplib             runpy               win32print
# _testimportmultiple imghdr              samplecodechart     win32process
# _testmultiphase     imp                 sched               win32profile
# _thread             importlib           secrets             win32ras
# _threading_local    importlib_metadata  select              win32rcparser
# _tkinter            inspect             selectors           win32security
# _tracemalloc        install_debugpy     servicemanager      win32service
# _warnings           interpreterInfo     setuptools          win32serviceutil
# _weakref            io                  sgmllib             win32timezone
# _weakrefset         ipaddress           shell_exec          win32trace
# _win32sysloader     ipykernel           shelve              win32traceutil
# _winapi             ipykernel_launcher  shlex               win32transaction
# _winxptheme         ipython_genutils    shutil              win32ts
# abc                 isapi               signal              win32ui
# adodbapi            itertools           simplejson          win32uiole
# afxres              jedi                site                win32verstamp
# aifc                json                six                 win32wnet
# antigravity         jupyter             smtpd               wincertstore
# appdirs             jupyter_client      smtplib             winerror
# argparse            jupyter_core        sndhdr              winioctlcon
# array               keyword             socket              winnt
# ast                 lib2to3             socketserver        winperf
# asynchat            linecache           soupsieve           winreg
# asyncio             locale              sqlite3             winsound
# asyncore            logging             sre_compile         winxpgui
# atexit              lxml                sre_constants       winxptheme
# audioop             lzma                sre_parse           wsgiref
# autdatayahoo        macpath             ssl                 xdrlib
# autoreload          mailbox             sspi                xml
# backcall            mailcap             sspicon             xmlrpc
# base64              marshal             stat                xxsubtype
# basicgraph          math                statistics          yahoo_fin
# bdb                 mimetypes           storemagic          yahoo_finance
# binascii            mmap                string              yfinance
# binhex              mmapfile            stringprep          zipapp
# bisect              mmsystem            struct              zipfile
# bs4                 modulefinder        subprocess          zipimport
# builtins            msilib              sunau               zipp
# bz2                 msvcrt              symbol              zlib
# cProfile            multiprocessing     symbolProvider      zmq
# calendar            multitasking        sympyprinting
# certifi             netbios             symtable
# cgi                 netrc               sys
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
